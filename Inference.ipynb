# %%
import pandas as pd
import Inference

# %%
dataset_path = "preprocessed_dataset.csv" 
data_explore = Inference.Inference(dataset_path)

# %%
data_explore.box_year_analysis()
# Out:
# Now start analysis
# year_release
# 1915             0
# 1927             0
# 1929             0
# 1930             0
# 1933             0
#            ...
# 2010     375451000
# 2011     220228000
# 2012     220680000
# 2013     955036800
# 2014    1114378340
# Name: box_office, Length: 86, dtype: int64

# %%
data_explore.gender_analysis_by_year()
# Out:
# Now start gender analysis
# subject_sex   Female  Male
# year_release
# 1915             0.0   1.0
# 1927             0.0   1.0
# 1929             0.0   1.0
# 1930             0.0   1.0
# 1933             1.0   1.0
# ...              ...   ...
# 2010             6.0  17.0
# 2011             6.0   7.0
# 2012             3.0  10.0
# 2013             4.0  32.0
# 2014             4.0  29.0
#
# [86 rows x 2 columns]
